# %%
HW = input ("have u done your home work")

clas = input ("have u done your coding class")

if HW == "yes" and clas == "yes" :

    print ("u can go out to play")

else :
    print ("stay at home")
# Out:
# have u done your home work no
