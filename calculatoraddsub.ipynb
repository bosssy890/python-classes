# %%
def add(a,b):
    add = a+b
    print("add is", add)

# %%
def subtract(a,b):
    subract = a-b
    print("subract is",subract)

# %%
n1 = int(input("enter number one"))
n2 = int(input("enter number two"))
add(n1,n2)
subtract(n1,n2)
# Out:
# enter number one 67
# enter number two 21
# add is 88
# subract is 46
