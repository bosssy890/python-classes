# %%
marks = int(input("enter marks"))

if marks>=0 and marks <= 100:
    print(" marks are valid ")

    if marks>= 50:
        print ("pass")
    else:
        print("fail")

else:
    print("invalid m")
