# %%
english = 40
math = 45
science = 48
arts = 49
coding = 47

sum = english + math + science + arts + coding

total = 250

percentage = (sum/total)*100

print (percentage)
# Out:
# 91.60000000000001
