# %%
age = 10

print(age)

type(age)
# Out:
# 10
# int

# %%
name = "muhammad"

print(name)

type(name)
# Out:
# muhammad
# str

# %%
value = True

print(value)

type(value)
# Out:
# True
# bool

# %%
marks = 9.5

print(marks)

type(marks)
# Out:
# 9.5
# float
