# %%
wer =(input("enter weather"))

if wer == "summer" :

    print("stay hydrated, wear light clothes, apply sun screen on daily basis")

if wer == "winter" :

     print("have warm soups, wear warm clothes, enjoy warm marshmallow parties")

    #proj weather times
