# %%
hf = ["cow","hen","camel","goat","deer","buffalo","sheep","lamb","fish"]

ani = input("enter the animal you want to check is halal")

if ani in hf:

    print("its halal.............go ahead and EAT!!!")

else :

    print("its haram .............but you can double check")
